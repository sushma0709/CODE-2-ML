# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Train_dataset.csv")
df.head(5)
# Out:
#   Stock Index    Index          Industry    VWAP  General Index    NAV  \
# 0         AA1     NYSE       Real Estate  700.29       12765.84  32.38
# 1         AA2     NYSE  Information Tech  214.52       12765.84  33.25
# 2         AA3     NYSE  Information Tech  943.42       12765.84  88.27
# 3         AA4      BSE         Materials  828.13       38182.08  73.66
# 4         AA5  S&P 500       Real Estate     NaN        3351.28  23.79
#
#    P/E Ratio  Volumes Traded  Inventory Turnover  Covid Impact (Beta)  \
# 0      45.35       1208599.0                5.05                -0.43
# 1     170.56      13753356.0                3.10                 0.23
# 2     143.58       6892003.0                7.70                 0.23
# 3     151.76       8316793.0                4.80                 0.03
# 4        NaN       3943312.0                8.06                -0.43
#
#    Tracking Error  Dollar Exchange Rate  Put-Call Ratio  P/B Ratio  \
# ...

# %%
df.shape
# Out:
# (7383, 15)

# %%
df.isnull().sum()
# Out:
# Stock Index               0
# Index                     0
# Industry                  0
# VWAP                     38
# General Index            62
# NAV                      61
# P/E Ratio               234
# Volumes Traded          268
# Inventory Turnover      399
# Covid Impact (Beta)     376
# Tracking Error           71
# Dollar Exchange Rate     77
# Put-Call Ratio           85
# P/B Ratio                25
# Stock Price               0
# dtype: int64

# %%
df.describe()
# Out:
#               VWAP  General Index          NAV    P/E Ratio  Volumes Traded  \
# count  7345.000000    7321.000000  7322.000000  7149.000000    7.115000e+03
# mean    486.188167   24218.079195    54.746004   105.543623    1.041827e+07
# std     278.280638   19602.174448    25.865877    55.284466    5.689059e+06
# min       5.250000    3351.280000    10.010000    10.020000    5.291170e+05
# 25%     247.100000   11270.150000    32.722500    57.630000    5.577644e+06
# 50%     488.380000   12765.840000    54.510000   105.770000    1.048238e+07
# 75%     724.020000   38182.080000    77.397500   154.130000    1.529882e+07
# max     965.210000   55722.000000    99.980000   199.970000    2.015445e+07
#
#        Inventory Turnover  Covid Impact (Beta)  Tracking Error  \
# count         6984.000000          7007.000000     7312.000000
# mean             5.436840             0.140654        0.038496
# std              1.655755             0.384544        0.013406
# ...

# %%
df["VWAP"]=df["VWAP"].fillna(486.18)
df["VWAP"].isnull().sum()
# Out:
# 0

# %%
df["P/E Ratio"]=df["P/E Ratio"].fillna(105.82)
df["VWAP"]=df["VWAP"].fillna(485.85)
df["General Index"]=df["General Index"].fillna(24178.27)
df["NAV"]=df["NAV"].fillna(54.75)
df["Volumes Traded"]=df["Volumes Traded"].fillna(1.04)
df["Inventory Turnover"]=df["Inventory Turnover"].fillna(5.44)
df["Covid Impact (Beta)"]=df["Covid Impact (Beta)"].fillna(0.14)
df["Tracking Error"]=df["Tracking Error"].fillna(0.03)
df["Dollar Exchange Rate"]=df["Dollar Exchange Rate"].fillna(33.99)
df["Put-Call Ratio"]=df["Put-Call Ratio"].fillna(0.94)
df["P/B Ratio"]=df["P/B Ratio"].fillna(5.01)

# %%
df.isnull().sum()
# Out:
# Stock Index             0
# Index                   0
# Industry                0
# VWAP                    0
# General Index           0
# NAV                     0
# P/E Ratio               0
# Volumes Traded          0
# Inventory Turnover      0
# Covid Impact (Beta)     0
# Tracking Error          0
# Dollar Exchange Rate    0
# Put-Call Ratio          0
# P/B Ratio               0
# Stock Price             0
# dtype: int64

# %%
df.shape
# Out:
# (7383, 15)

# %%
df1=df.drop(["Stock Index","Index","Industry"],axis='columns')
df1.head(4)
# Out:
#      VWAP  General Index    NAV  P/E Ratio  Volumes Traded  \
# 0  700.29       12765.84  32.38      45.35       1208599.0
# 1  214.52       12765.84  33.25     170.56      13753356.0
# 2  943.42       12765.84  88.27     143.58       6892003.0
# 3  828.13       38182.08  73.66     151.76       8316793.0
#
#    Inventory Turnover  Covid Impact (Beta)  Tracking Error  \
# 0                5.05                -0.43          0.0520
# 1                3.10                 0.23          0.0164
# 2                7.70                 0.23          0.0396
# 3                4.80                 0.03          0.0431
#
#    Dollar Exchange Rate  Put-Call Ratio  P/B Ratio  Stock Price
# 0                   1.0            0.61       9.20   156.987851
# 1                   1.0            0.94       6.91   560.859622
# 2                   1.0            0.94       6.09  1279.732874
# 3                  74.9            1.11       5.60  1121.787632

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)

# %%
df1=df1.astype(float)

# %%
x=df1.drop("Stock Price",axis=1)
y=df1["Stock Price"]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
new=pd.read_csv("Stock_Price.csv")
new.head(2)
# Out:
#   Stock Index Index   Industry    VWAP  General Index    NAV  P/E Ratio  \
# 0      AC3235   NSE  Materials   53.30       11270.15  44.59     185.09
# 1      AC3236   JSE     Energy  749.34       55722.00  74.20      34.01
#
#    Volumes Traded  Inventory Turnover  Covid Impact (Beta)  Tracking Error  \
# 0      12067855.0                2.78                 0.03          0.0330
# 1       6172474.0                6.78                 0.11          0.0464
#
#    Dollar Exchange Rate  Put-Call Ratio  P/B Ratio
# 0                  74.9            0.80       4.66
# 1                  17.7            0.86       6.11

# %%
new1=new.drop(["Index","Industry"],axis='columns')
new2=new.drop(["Index","Industry","Stock Index"],axis='columns')
new2=new2.astype(float)

# %%
new2.isnull().sum()
# Out:
# VWAP                     12
# General Index           271
# NAV                     275
# P/E Ratio               292
# Volumes Traded           48
# Inventory Turnover       30
# Covid Impact (Beta)      31
# Tracking Error          126
# Dollar Exchange Rate    143
# Put-Call Ratio          429
# P/B Ratio               138
# dtype: int64

# %%
new.describe()
# Out:
#               VWAP  General Index          NAV    P/E Ratio  Volumes Traded  \
# count  3319.000000    3060.000000  3056.000000  3039.000000    3.283000e+03
# mean    488.572588   25099.383680    54.257196   104.731629    1.018308e+07
# std     281.559056   19886.618464    26.184335    54.231743    5.645921e+06
# min       5.490000    3351.280000    10.100000    10.050000    5.244620e+05
# 25%     241.245000   11270.150000    31.100000    59.050000    5.282625e+06
# 50%     488.410000   12765.840000    54.170000   104.550000    1.019403e+07
# 75%     739.465000   38182.080000    77.002500   151.110000    1.507125e+07
# max     965.080000   55722.000000    99.960000   199.970000    2.013252e+07
#
#        Inventory Turnover  Covid Impact (Beta)  Tracking Error  \
# count         3301.000000          3300.000000     3205.000000
# mean             5.422872             0.139082        0.038340
# std              1.669301             0.385717        0.013208
# ...

# %%
new2=new2.fillna(new2.mean(axis=0))

# %%
new2.isnull().sum()
# Out:
# VWAP                    0
# General Index           0
# NAV                     0
# P/E Ratio               0
# Volumes Traded          0
# Inventory Turnover      0
# Covid Impact (Beta)     0
# Tracking Error          0
# Dollar Exchange Rate    0
# Put-Call Ratio          0
# P/B Ratio               0
# dtype: int64

# %%
Stock_Price=lr.predict(new2)
new1["Stock Price"]=Stock_Price
#Stock_Price

# %%
new1.head(2)
# Out:
#   Stock Index    VWAP  General Index    NAV  P/E Ratio  Volumes Traded  \
# 0      AC3235   53.30       11270.15  44.59     185.09      12067855.0
# 1      AC3236  749.34       55722.00  74.20      34.01       6172474.0
#
#    Inventory Turnover  Covid Impact (Beta)  Tracking Error  \
# 0                2.78                 0.03          0.0330
# 1                6.78                 0.11          0.0464
#
#    Dollar Exchange Rate  Put-Call Ratio  P/B Ratio  Stock Price
# 0                  74.9            0.80       4.66   868.714431
# 1                  17.7            0.86       6.11   407.485073

# %%
data=new1[["Stock Index","Stock Price"]]

data.to_excel("02.xlsx")
